# %%
import case_scraper
import find_cases
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
c2018 = find_cases.find_cases("2018")

# %%
c2018
# Out:
#                                           Description               Date  \
# 0                       ARTIS v. DISTRICT OF COLUMBIA   January 22, 2018
# 1                DIGITAL REALTY TRUST, INC. v. SOMERS  February 21, 2018
# 2   MERIT MANAGEMENT GROUP, LP v. FTI CONSULTING, ...  February 27, 2018
# 3                              MURPHY v. SMITH ET AL.  February 21, 2018
# 4   OIL STATES ENERGY SERVICES, LLC v. GREENE'S EN...     April 24, 2018
# ..                                                ...                ...
# 89  WASHINGTON, PETITIONER  v.  UNITED STATES, ET AL.      June 11, 2018
# 90           WESTERNGECO LLC v. ION GEOPHYSICAL CORP.      June 22, 2018
# 91  WEYERHAEUSER CO. v. UNITED STATES FISH AND WIL...  November 27, 2018
# 92                          WILSON v. SELLERS, WARDEN     April 17, 2018
# 93     WISCONSIN CENTRAL LTD. ET AL. v. UNITED STATES      June 21, 2018
#
#    Docket Number                                               Link
# ...

# %%
case_scraper.case_scraper(c2018["Link"][0])
# Out:
# '\n\nUnited States Supreme Court\nARTIS v. DISTRICT OF COLUMBIA(2018)\nNo. 16-460\nArgued: November 1, 2017Decided: January 22, 2018\n\n\nFederal district courts may exercise supplemental jurisdiction over state claims not otherwise within their adjudicatory authority if those claims are "part of the same case or controversy" as the federal claims the plaintiff asserts.  28 U.\xa0S.\xa0C. §1367(a).  When a district court dismisses all claims independently qualifying for the exercise of federal jurisdiction, it ordinarily also dismisses all related state claims.  See §1367(c)(3).  Section 1367(d) provides that the "period of limitations for" refiling in state court a state claim so dismissed "shall be tolled while the claim is pending [in federal court] and for a period of 30 days after it is dismissed unless State law provides for a longer tolling period."  \n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0When petitioner Artis filed a federal-court suit against respondent District of Columb
# ...

# %%
for i in np.arange(5):
    print(case_scraper.case_scraper(c2018["Link"][i]))
# Out:
# United States Supreme Court
# ARTIS v. DISTRICT OF COLUMBIA(2018)
# No. 16-460
# Argued: November 1, 2017Decided: January 22, 2018
#
#
# Federal district courts may exercise supplemental jurisdiction over state claims not otherwise within their adjudicatory authority if those claims are "part of the same case or controversy" as the federal claims the plaintiff asserts.  28 U. S. C. §1367(a).  When a district court dismisses all claims independently qualifying for the exercise of federal jurisdiction, it ordinarily also dismisses all related state claims.  See §1367(c)(3).  Section 1367(d) provides that the "period of limitations for" refiling in state court a state claim so dismissed "shall be tolled while the claim is pending [in federal court] and for a period of 30 days after it is dismissed unless State law provides for a longer tolling period."
# ...

# %%
c2018["Opinion"] = c2018["Link"].apply(case_scraper.case_scraper)

# %%
c2018
# Out:
#                                           Description               Date  \
# 0                       ARTIS v. DISTRICT OF COLUMBIA   January 22, 2018
# 1                DIGITAL REALTY TRUST, INC. v. SOMERS  February 21, 2018
# 2   MERIT MANAGEMENT GROUP, LP v. FTI CONSULTING, ...  February 27, 2018
# 3                              MURPHY v. SMITH ET AL.  February 21, 2018
# 4   OIL STATES ENERGY SERVICES, LLC v. GREENE'S EN...     April 24, 2018
# ..                                                ...                ...
# 89  WASHINGTON, PETITIONER  v.  UNITED STATES, ET AL.      June 11, 2018
# 90           WESTERNGECO LLC v. ION GEOPHYSICAL CORP.      June 22, 2018
# 91  WEYERHAEUSER CO. v. UNITED STATES FISH AND WIL...  November 27, 2018
# 92                          WILSON v. SELLERS, WARDEN     April 17, 2018
# 93     WISCONSIN CENTRAL LTD. ET AL. v. UNITED STATES      June 21, 2018
#
#    Docket Number                                               Link  \
# ...

# %%
c2018.to_json("2018_Opinions.json")

# %%
print(pd.read_json("2018_Opinions.json")["Opinion"][0])
# Out:
# United States Supreme Court
# ARTIS v. DISTRICT OF COLUMBIA(2018)
# No. 16-460
# Argued: November 1, 2017Decided: January 22, 2018
#
#
# Federal district courts may exercise supplemental jurisdiction over state claims not otherwise within their adjudicatory authority if those claims are "part of the same case or controversy" as the federal claims the plaintiff asserts.  28 U. S. C. §1367(a).  When a district court dismisses all claims independently qualifying for the exercise of federal jurisdiction, it ordinarily also dismisses all related state claims.  See §1367(c)(3).  Section 1367(d) provides that the "period of limitations for" refiling in state court a state claim so dismissed "shall be tolled while the claim is pending [in federal court] and for a period of 30 days after it is dismissed unless State law provides for a longer tolling period."
# ...

# %%
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in c2018["Opinion"][np.arange(5)]: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 1920, height = 1080, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (100, 100), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
